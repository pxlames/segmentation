# %%
# import 差分约束 as DifferentialConnection
import matplotlib.pyplot as plt
from scipy.spatial import distance
from skimage.measure import label, regionprops
import numpy as np
from PIL import Image
import cv2
import numpy as np
from skimage.morphology import skeletonize
from skimage.measure import label, regionprops
import matplotlib.pyplot as plt
import random
import sys
import networkx as nx
from scipy.ndimage import distance_transform_edt
from scipy.spatial import distance
from numpy.polynomial.polynomial import Polynomial
from no_one提取图结构 import segment_and_visualize_vessels,crop_image,visualize_segments_andNo,visualize_segment_graph

# 获取连通组件
path = '/home/xkw/pxlames/segmentation/gt_05.png'
# 一条分段
# position = (220, 230)  # 裁剪的起始位置 (x, y)
# size = (80, 60)  # 裁剪区域的尺寸 (width, height)
# 一条不分段
# position = (300, 230)  # 裁剪的起始位置 (x, y)
# size = (80, 60)  # 裁剪区域的尺寸 (width, height)
# 更大尺度
# position = (300, 250)  # 裁剪的起始位置 (x, y)
# size = (150, 150)  # 裁剪区域的尺寸 (width, height)
# position = (600, 230)  # 裁剪的起始位置 (x, y)
# size = (80, 60)  # 裁剪区域的尺寸 (width, height)
position = (160, 160)  # 裁剪的起始位置 (x, y)
size = (300, 300)  # 裁剪区域的尺寸 (width, height)
cropped_image = crop_image(path, position, size,False)
pred = np.array(cropped_image) 

plt.figure(figsize=(12, 8))
plt.imshow(cropped_image, cmap='gray')

_, binary = cv2.threshold(pred, 127, 255, cv2.THRESH_BINARY)
segment_graph = segment_and_visualize_vessels(binary.copy())
# Out:
# Segment 1:
#   Endpoints: ((34, 289), (74, 252))
#   Direction (k): 2.32 radians
#   Length: 54.49 pixels
#   Pixel Count: 49
# ----------------------------------------
# Segment 2:
#   Endpoints: ((37, 322), (62, 314))
#   Direction (k): 1.88 radians
#   Length: 26.25 pixels
#   Pixel Count: 26
# ----------------------------------------
# Segment 3:
#   Endpoints: ((41, 219), (55, 211))
#   Direction (k): 2.09 radians
#   Length: 16.12 pixels
#   Pixel Count: 15
# ----------------------------------------
# Segment 4:
#   Endpoints: ((44, 348), (65, 314))
#   Direction (k): 2.59 radians
#   Length: 39.96 pixels
#   Pixel Count: 42
# ----------------------------------------
# Segment 5:
#   Endpoints: ((56, 214), (60, 227))
#   Direction (k): 0.30 radians
#   Length: 13.60 pixels
#   Pixel Count: 15
# ----------------------------------------
# Segment 6:
#   Endpoints: ((57, 209), (100, 173))
#   Direction (k): 2.27 radians
#   Length: 56.08 pixels
#   Pixel Count: 51
# ----------------------------------------
# Segment 7:
#   Endpoints: ((57, 384), (81, 374))
#   Direction (k): 1.97 radians
#   Length: 26.00 pixels
#   Pixel Count: 25
# ----------------------------------------
# Segment 8:
#   Endpoints: ((63, 160), (98, 170))
#   Direction (k): 1.29 radians
#   Length: 36.40 pixels
#   Pixel Count: 36
# ----------------------------------------
# Segment 9:
#   Endpoints: ((64, 275), (66, 307))
#   Direction (k): 0.06 radians
#   Length: 32.06 pixels
#   Pixel Count: 55
# ----------------------------------------
# Segment 10:
#   Endpoints: ((65, 311), (65, 311))
#   Direction (k): 0.00 radians
#   Length: 0.00 pixels
#   Pixel Count: 1
# ----------------------------------------
# Segment 11:
#   Endpoints: ((68, 308), (80, 303))
#   Direction (k): 1.97 radians
#   Length: 13.00 pixels
#   Pixel Count: 13
# ----------------------------------------
# Segment 12:
#   Endpoints: ((78, 251), (103, 234))
#   Direction (k): 2.17 radians
#   Length: 30.23 pixels
#   Pixel Count: 26
# ----------------------------------------
# Segment 13:
#   Endpoints: ((81, 301), (96, 277))
#   Direction (k): 2.58 radians
#   Length: 28.30 pixels
#   Pixel Count: 26
# ----------------------------------------
# Segment 14:
#   Endpoints: ((82, 303), (86, 316))
#   Direction (k): 0.30 radians
#   Length: 13.60 pixels
#   Pixel Count: 14
# ----------------------------------------
# Segment 15:
#   Endpoints: ((83, 367), (83, 371))
#   Direction (k): 0.00 radians
#   Length: 4.00 pixels
#   Pixel Count: 52
# ----------------------------------------
# Segment 16:
#   Endpoints: ((84, 373), (109, 389))
#   Direction (k): 1.00 radians
#   Length: 29.68 pixels
#   Pixel Count: 27
# ----------------------------------------
# Segment 17:
#   Endpoints: ((86, 408), (97, 407))
#   Direction (k): 1.66 radians
#   Length: 11.05 pixels
#   Pixel Count: 12
# ----------------------------------------
# Segment 18:
#   Endpoints: ((88, 318), (101, 320))
#   Direction (k): 1.42 radians
#   Length: 13.15 pixels
#   Pixel Count: 14
# ----------------------------------------
# Segment 19:
#   Endpoints: ((90, 474), (99, 409))
#   Direction (k): 3.00 radians
#   Length: 65.62 pixels
#   Pixel Count: 66
# ----------------------------------------
# Segment 20:
#   Endpoints: ((94, 120), (100, 168))
#   Direction (k): 0.12 radians
#   Length: 48.37 pixels
#   Pixel Count: 49
# ----------------------------------------
# Segment 21:
#   Endpoints: ((97, 273), (97, 275))
#   Direction (k): 0.00 radians
#   Length: 2.00 pixels
#   Pixel Count: 38
# ----------------------------------------
# Segment 22:
#   Endpoints: ((98, 277), (110, 279))
#   Direction (k): 1.41 radians
#   Length: 12.17 pixels
#   Pixel Count: 13
# ----------------------------------------
# Segment 23:
#   Endpoints: ((100, 403), (100, 405))
#   Direction (k): 0.00 radians
#   Length: 2.00 pixels
#   Pixel Count: 15
# ----------------------------------------
# Segment 24:
#   Endpoints: ((103, 172), (132, 174))
#   Direction (k): 1.50 radians
#   Length: 29.07 pixels
#   Pixel Count: 30
# ----------------------------------------
# Segment 25:
#   Endpoints: ((106, 230), (106, 231))
#   Direction (k): 0.00 radians
#   Length: 1.00 pixels
#   Pixel Count: 2
# ----------------------------------------
# Segment 26:
#   Endpoints: ((106, 234), (107, 235))
#   Direction (k): 0.79 radians
#   Length: 1.41 pixels
#   Pixel Count: 2
# ----------------------------------------
# Segment 27:
#   Endpoints: ((109, 225), (109, 227))
#   Direction (k): 0.00 radians
#   Length: 2.00 pixels
#   Pixel Count: 43
# ----------------------------------------
# Segment 28:
#   Endpoints: ((110, 230), (111, 231))
#   Direction (k): 0.79 radians
#   Length: 1.41 pixels
#   Pixel Count: 2
# ----------------------------------------
# Segment 29:
#   Endpoints: ((110, 235), (111, 233))
#   Direction (k): 2.68 radians
#   Length: 2.24 pixels
#   Pixel Count: 3
# ----------------------------------------
# Segment 30:
#   Endpoints: ((111, 93), (211, 65))
#   Direction (k): 1.84 radians
#   Length: 103.85 pixels
#   Pixel Count: 104
# ----------------------------------------
# Segment 31:
#   Endpoints: ((111, 343), (111, 349))
#   Direction (k): 0.00 radians
#   Length: 6.00 pixels
#   Pixel Count: 40
# ----------------------------------------
# Segment 32:
#   Endpoints: ((111, 353), (112, 390))
#   Direction (k): 0.03 radians
#   Length: 37.01 pixels
#   Pixel Count: 39
# ----------------------------------------
# Segment 33:
#   Endpoints: ((113, 232), (127, 194))
#   Direction (k): 2.79 radians
#   Length: 40.50 pixels
#   Pixel Count: 39
# ----------------------------------------
# Segment 34:
#   Endpoints: ((113, 351), (133, 369))
#   Direction (k): 0.84 radians
#   Length: 26.91 pixels
#   Pixel Count: 26
# ----------------------------------------
# Segment 35:
#   Endpoints: ((120, 239), (120, 245))
#   Direction (k): 0.00 radians
#   Length: 6.00 pixels
#   Pixel Count: 35
# ----------------------------------------
# Segment 36:
#   Endpoints: ((120, 298), (122, 308))
#   Direction (k): 0.20 radians
#   Length: 10.20 pixels
#   Pixel Count: 61
# ----------------------------------------
# Segment 37:
#   Endpoints: ((124, 246), (142, 247))
#   Direction (k): 1.52 radians
#   Length: 18.03 pixels
#   Pixel Count: 19
# ----------------------------------------
# Segment 38:
#   Endpoints: ((124, 308), (155, 304))
#   Direction (k): 1.70 radians
#   Length: 31.26 pixels
#   Pixel Count: 32
# ----------------------------------------
# Segment 39:
#   Endpoints: ((126, 445), (128, 448))
#   Direction (k): 0.59 radians
#   Length: 3.61 pixels
#   Pixel Count: 4
# ----------------------------------------
# Segment 40:
#   Endpoints: ((127, 454), (127, 456))
#   Direction (k): 0.00 radians
#   Length: 2.00 pixels
#   Pixel Count: 5
# ----------------------------------------
# Segment 41:
#   Endpoints: ((128, 473), (128, 478))
#   Direction (k): 0.00 radians
#   Length: 5.00 pixels
#   Pixel Count: 21
# ----------------------------------------
# Segment 42:
#   Endpoints: ((129, 205), (129, 208))
#   Direction (k): 0.00 radians
#   Length: 3.00 pixels
#   Pixel Count: 16
# ----------------------------------------
# Segment 43:
#   Endpoints: ((130, 190), (133, 186))
#   Direction (k): 2.50 radians
#   Length: 5.00 pixels
#   Pixel Count: 5
# ----------------------------------------
# Segment 44:
#   Endpoints: ((130, 452), (134, 456))
#   Direction (k): 0.79 radians
#   Length: 5.66 pixels
#   Pixel Count: 5
# ----------------------------------------
# Segment 45:
#   Endpoints: ((131, 210), (147, 208))
#   Direction (k): 1.70 radians
#   Length: 16.12 pixels
#   Pixel Count: 17
# ----------------------------------------
# Segment 46:
#   Endpoints: ((131, 449), (144, 450))
#   Direction (k): 1.49 radians
#   Length: 13.04 pixels
#   Pixel Count: 14
# ----------------------------------------
# Segment 47:
#   Endpoints: ((134, 176), (134, 183))
#   Direction (k): 0.00 radians
#   Length: 7.00 pixels
#   Pixel Count: 8
# ----------------------------------------
# Segment 48:
#   Endpoints: ((135, 372), (135, 372))
#   Direction (k): 0.00 radians
#   Length: 0.00 pixels
#   Pixel Count: 1
# ----------------------------------------
# Segment 49:
#   Endpoints: ((136, 173), (142, 168))
#   Direction (k): 2.27 radians
#   Length: 7.81 pixels
#   Pixel Count: 7
# ----------------------------------------
# Segment 50:
#   Endpoints: ((136, 184), (143, 180))
#   Direction (k): 2.09 radians
#   Length: 8.06 pixels
#   Pixel Count: 9
# ----------------------------------------
# Segment 51:
#   Endpoints: ((136, 375), (164, 422))
#   Direction (k): 0.54 radians
#   Length: 54.71 pixels
#   Pixel Count: 49
# ----------------------------------------
# Segment 52:
#   Endpoints: ((137, 369), (145, 370))
#   Direction (k): 1.45 radians
#   Length: 8.06 pixels
#   Pixel Count: 9
# ----------------------------------------
# Segment 53:
#   Endpoints: ((138, 373), (146, 372))
#   Direction (k): 1.70 radians
#   Length: 8.06 pixels
#   Pixel Count: 9
# ----------------------------------------
# Segment 54:
#   Endpoints: ((142, 456), (142, 459))
#   Direction (k): 0.00 radians
#   Length: 3.00 pixels
#   Pixel Count: 8
# ----------------------------------------
# Segment 55:
#   Endpoints: ((144, 462), (144, 462))
#   Direction (k): 0.00 radians
#   Length: 0.00 pixels
#   Pixel Count: 1
# ----------------------------------------
# Segment 56:
#   Endpoints: ((145, 176), (145, 176))
#   Direction (k): 0.00 radians
#   Length: 0.00 pixels
#   Pixel Count: 1
# ----------------------------------------
# Segment 57:
#   Endpoints: ((146, 184), (146, 186))
#   Direction (k): 0.00 radians
#   Length: 2.00 pixels
#   Pixel Count: 3
# ----------------------------------------
# Segment 58:
#   Endpoints: ((147, 132), (151, 154))
#   Direction (k): 0.18 radians
#   Length: 22.36 pixels
#   Pixel Count: 107
# ----------------------------------------
# Segment 59:
#   Endpoints: ((147, 171), (147, 173))
#   Direction (k): 0.00 radians
#   Length: 2.00 pixels
#   Pixel Count: 3
# ----------------------------------------
# Segment 60:
#   Endpoints: ((147, 259), (156, 265))
#   Direction (k): 0.98 radians
#   Length: 10.82 pixels
#   Pixel Count: 10
# ----------------------------------------
# Segment 61:
#   Endpoints: ((147, 350), (147, 351))
#   Direction (k): 0.00 radians
#   Length: 1.00 pixels
#   Pixel Count: 19
# ----------------------------------------
# Segment 62:
#   Endpoints: ((147, 370), (169, 365))
#   Direction (k): 1.79 radians
#   Length: 22.56 pixels
#   Pixel Count: 23
# ----------------------------------------
# Segment 63:
#   Endpoints: ((148, 176), (149, 178))
#   Direction (k): 0.46 radians
#   Length: 2.24 pixels
#   Pixel Count: 3
# ----------------------------------------
# Segment 64:
#   Endpoints: ((148, 183), (154, 187))
#   Direction (k): 0.98 radians
#   Length: 7.21 pixels
#   Pixel Count: 7
# ----------------------------------------
# Segment 65:
#   Endpoints: ((148, 451), (165, 429))
#   Direction (k): 2.48 radians
#   Length: 27.80 pixels
#   Pixel Count: 26
# ----------------------------------------
# Segment 66:
#   Endpoints: ((149, 164), (149, 165))
#   Direction (k): 0.00 radians
#   Length: 1.00 pixels
#   Pixel Count: 8
# ----------------------------------------
# Segment 67:
#   Endpoints: ((151, 233), (158, 240))
#   Direction (k): 0.79 radians
#   Length: 9.90 pixels
#   Pixel Count: 9
# ----------------------------------------
# Segment 68:
#   Endpoints: ((151, 276), (155, 280))
#   Direction (k): 0.79 radians
#   Length: 5.66 pixels
#   Pixel Count: 16
# ----------------------------------------
# Segment 69:
#   Endpoints: ((152, 247), (152, 252))
#   Direction (k): 0.00 radians
#   Length: 5.00 pixels
#   Pixel Count: 11
# ----------------------------------------
# Segment 70:
#   Endpoints: ((154, 156), (169, 148))
#   Direction (k): 2.06 radians
#   Length: 17.00 pixels
#   Pixel Count: 17
# ----------------------------------------
# Segment 71:
#   Endpoints: ((156, 229), (162, 231))
#   Direction (k): 1.25 radians
#   Length: 6.32 pixels
#   Pixel Count: 7
# ----------------------------------------
# Segment 72:
#   Endpoints: ((156, 331), (164, 338))
#   Direction (k): 0.85 radians
#   Length: 10.63 pixels
#   Pixel Count: 9
# ----------------------------------------
# Segment 73:
#   Endpoints: ((158, 247), (159, 252))
#   Direction (k): 0.20 radians
#   Length: 5.10 pixels
#   Pixel Count: 9
# ----------------------------------------
# Segment 74:
#   Endpoints: ((160, 193), (161, 200))
#   Direction (k): 0.14 radians
#   Length: 7.07 pixels
#   Pixel Count: 43
# ----------------------------------------
# Segment 75:
#   Endpoints: ((160, 238), (163, 237))
#   Direction (k): 1.89 radians
#   Length: 3.16 pixels
#   Pixel Count: 4
# ----------------------------------------
# Segment 76:
#   Endpoints: ((160, 264), (169, 262))
#   Direction (k): 1.79 radians
#   Length: 9.22 pixels
#   Pixel Count: 10
# ----------------------------------------
# Segment 77:
#   Endpoints: ((162, 203), (164, 224))
#   Direction (k): 0.09 radians
#   Length: 21.10 pixels
#   Pixel Count: 22
# ----------------------------------------
# Segment 78:
#   Endpoints: ((162, 240), (164, 241))
#   Direction (k): 1.11 radians
#   Length: 2.24 pixels
#   Pixel Count: 3
# ----------------------------------------
# Segment 79:
#   Endpoints: ((164, 201), (179, 204))
#   Direction (k): 1.37 radians
#   Length: 15.30 pixels
#   Pixel Count: 16
# ----------------------------------------
# Segment 80:
#   Endpoints: ((164, 228), (164, 229))
#   Direction (k): 0.00 radians
#   Length: 1.00 pixels
#   Pixel Count: 2
# ----------------------------------------
# Segment 81:
#   Endpoints: ((165, 233), (165, 235))
#   Direction (k): 0.00 radians
#   Length: 2.00 pixels
#   Pixel Count: 3
# ----------------------------------------
# Segment 82:
#   Endpoints: ((166, 226), (166, 226))
#   Direction (k): 0.00 radians
#   Length: 0.00 pixels
#   Pixel Count: 1
# ----------------------------------------
# Segment 83:
#   Endpoints: ((166, 238), (166, 239))
#   Direction (k): 0.00 radians
#   Length: 1.00 pixels
#   Pixel Count: 2
# ----------------------------------------
# Segment 84:
#   Endpoints: ((166, 425), (166, 426))
#   Direction (k): 0.00 radians
#   Length: 1.00 pixels
#   Pixel Count: 2
# ----------------------------------------
# Segment 85:
#   Endpoints: ((167, 242), (171, 260))
#   Direction (k): 0.22 radians
#   Length: 18.44 pixels
#   Pixel Count: 19
# ----------------------------------------
# Segment 86:
#   Endpoints: ((167, 340), (185, 338))
#   Direction (k): 1.68 radians
#   Length: 18.11 pixels
#   Pixel Count: 19
# ----------------------------------------
# Segment 87:
#   Endpoints: ((167, 422), (195, 391))
#   Direction (k): 2.41 radians
#   Length: 41.77 pixels
#   Pixel Count: 34
# ----------------------------------------
# Segment 88:
#   Endpoints: ((168, 428), (190, 458))
#   Direction (k): 0.63 radians
#   Length: 37.20 pixels
#   Pixel Count: 38
# ----------------------------------------
# Segment 89:
#   Endpoints: ((169, 223), (169, 224))
#   Direction (k): 0.00 radians
#   Length: 1.00 pixels
#   Pixel Count: 19
# ----------------------------------------
# Segment 90:
#   Endpoints: ((169, 227), (176, 243))
#   Direction (k): 0.41 radians
#   Length: 17.46 pixels
#   Pixel Count: 17
# ----------------------------------------
# Segment 91:
#   Endpoints: ((171, 150), (171, 155))
#   Direction (k): 0.00 radians
#   Length: 5.00 pixels
#   Pixel Count: 6
# ----------------------------------------
# Segment 92:
#   Endpoints: ((172, 145), (172, 146))
#   Direction (k): 0.00 radians
#   Length: 1.00 pixels
#   Pixel Count: 18
# ----------------------------------------
# Segment 93:
#   Endpoints: ((172, 263), (183, 274))
#   Direction (k): 0.79 radians
#   Length: 15.56 pixels
#   Pixel Count: 13
# ----------------------------------------
# Segment 94:
#   Endpoints: ((172, 382), (191, 384))
#   Direction (k): 1.47 radians
#   Length: 19.10 pixels
#   Pixel Count: 20
# ----------------------------------------
# Segment 95:
#   Endpoints: ((173, 157), (182, 203))
#   Direction (k): 0.19 radians
#   Length: 46.87 pixels
#   Pixel Count: 49
# ----------------------------------------
# Segment 96:
#   Endpoints: ((175, 149), (175, 149))
#   Direction (k): 0.00 radians
#   Length: 0.00 pixels
#   Pixel Count: 1
# ----------------------------------------
# Segment 97:
#   Endpoints: ((177, 147), (190, 133))
#   Direction (k): 2.39 radians
#   Length: 19.10 pixels
#   Pixel Count: 18
# ----------------------------------------
# Segment 98:
#   Endpoints: ((180, 44), (195, 47))
#   Direction (k): 1.37 radians
#   Length: 15.30 pixels
#   Pixel Count: 16
# ----------------------------------------
# Segment 99:
#   Endpoints: ((183, 206), (194, 212))
#   Direction (k): 1.07 radians
#   Length: 12.53 pixels
#   Pixel Count: 12
# ----------------------------------------
# Segment 100:
#   Endpoints: ((186, 274), (211, 264))
#   Direction (k): 1.95 radians
#   Length: 26.93 pixels
#   Pixel Count: 26
# ----------------------------------------
# Segment 101:
#   Endpoints: ((186, 277), (191, 290))
#   Direction (k): 0.37 radians
#   Length: 13.93 pixels
#   Pixel Count: 14
# ----------------------------------------
# Segment 102:
#   Endpoints: ((187, 316), (187, 336))
#   Direction (k): 0.00 radians
#   Length: 20.00 pixels
#   Pixel Count: 25
# ----------------------------------------
# Segment 103:
#   Endpoints: ((187, 497), (187, 501))
#   Direction (k): 0.00 radians
#   Length: 4.00 pixels
#   Pixel Count: 41
# ----------------------------------------
# Segment 104:
#   Endpoints: ((188, 127), (188, 127))
#   Direction (k): 0.00 radians
#   Length: 0.00 pixels
#   Pixel Count: 1
# ----------------------------------------
# Segment 105:
#   Endpoints: ((188, 130), (189, 131))
#   Direction (k): 0.79 radians
#   Length: 1.41 pixels
#   Pixel Count: 2
# ----------------------------------------
# Segment 106:
#   Endpoints: ((188, 303), (188, 308))
#   Direction (k): 0.00 radians
#   Length: 5.00 pixels
#   Pixel Count: 16
# ----------------------------------------
# Segment 107:
#   Endpoints: ((189, 339), (191, 345))
#   Direction (k): 0.32 radians
#   Length: 6.32 pixels
#   Pixel Count: 7
# ----------------------------------------
# Segment 108:
#   Endpoints: ((190, 124), (207, 107))
#   Direction (k): 2.36 radians
#   Length: 24.04 pixels
#   Pixel Count: 21
# ----------------------------------------
# Segment 109:
#   Endpoints: ((190, 310), (207, 316))
#   Direction (k): 1.23 radians
#   Length: 18.03 pixels
#   Pixel Count: 18
# ----------------------------------------
# Segment 110:
#   Endpoints: ((191, 131), (192, 130))
#   Direction (k): 2.36 radians
#   Length: 1.41 pixels
#   Pixel Count: 2
# ----------------------------------------
# Segment 111:
#   Endpoints: ((192, 347), (204, 370))
#   Direction (k): 0.48 radians
#   Length: 25.94 pixels
#   Pixel Count: 24
# ----------------------------------------
# Segment 112:
#   Endpoints: ((192, 442), (208, 448))
#   Direction (k): 1.21 radians
#   Length: 17.09 pixels
#   Pixel Count: 18
# ----------------------------------------
# Segment 113:
#   Endpoints: ((193, 345), (204, 334))
#   Direction (k): 2.36 radians
#   Length: 15.56 pixels
#   Pixel Count: 13
# ----------------------------------------
# Segment 114:
#   Endpoints: ((193, 459), (198, 459))
#   Direction (k): 1.57 radians
#   Length: 5.00 pixels
#   Pixel Count: 6
# ----------------------------------------
# Segment 115:
#   Endpoints: ((194, 37), (197, 45))
#   Direction (k): 0.36 radians
#   Length: 8.54 pixels
#   Pixel Count: 9
# ----------------------------------------
# Segment 116:
#   Endpoints: ((194, 291), (210, 291))
#   Direction (k): 1.57 radians
#   Length: 16.00 pixels
#   Pixel Count: 17
# ----------------------------------------
# Segment 117:
#   Endpoints: ((194, 383), (197, 382))
#   Direction (k): 1.89 radians
#   Length: 3.16 pixels
#   Pixel Count: 4
# ----------------------------------------
# Segment 118:
#   Endpoints: ((194, 386), (194, 387))
#   Direction (k): 0.00 radians
#   Length: 1.00 pixels
#   Pixel Count: 2
# ----------------------------------------
# Segment 119:
#   Endpoints: ((195, 126), (199, 124))
#   Direction (k): 2.03 radians
#   Length: 4.47 pixels
#   Pixel Count: 5
# ----------------------------------------
# Segment 120:
#   Endpoints: ((196, 214), (210, 229))
#   Direction (k): 0.75 radians
#   Length: 20.52 pixels
#   Pixel Count: 19
# ----------------------------------------
# Segment 121:
#   Endpoints: ((197, 387), (197, 388))
#   Direction (k): 0.00 radians
#   Length: 1.00 pixels
#   Pixel Count: 5
# ----------------------------------------
# Segment 122:
#   Endpoints: ((198, 212), (227, 194))
#   Direction (k): 2.13 radians
#   Length: 34.13 pixels
#   Pixel Count: 33
# ----------------------------------------
# Segment 123:
#   Endpoints: ((199, 47), (215, 60))
#   Direction (k): 0.89 radians
#   Length: 20.62 pixels
#   Pixel Count: 17
# ----------------------------------------
# Segment 124:
#   Endpoints: ((200, 381), (204, 378))
#   Direction (k): 2.21 radians
#   Length: 5.00 pixels
#   Pixel Count: 5
# ----------------------------------------
# Segment 125:
#   Endpoints: ((200, 457), (207, 451))
#   Direction (k): 2.28 radians
#   Length: 9.22 pixels
#   Pixel Count: 8
# ----------------------------------------
# Segment 126:
#   Endpoints: ((201, 127), (215, 177))
#   Direction (k): 0.27 radians
#   Length: 51.92 pixels
#   Pixel Count: 51
# ----------------------------------------
# Segment 127:
#   Endpoints: ((201, 414), (210, 415))
#   Direction (k): 1.46 radians
#   Length: 9.06 pixels
#   Pixel Count: 10
# ----------------------------------------
# Segment 128:
#   Endpoints: ((201, 460), (207, 467))
#   Direction (k): 0.71 radians
#   Length: 9.22 pixels
#   Pixel Count: 10
# ----------------------------------------
# Segment 129:
#   Endpoints: ((202, 326), (209, 319))
#   Direction (k): 2.36 radians
#   Length: 9.90 pixels
#   Pixel Count: 14
# ----------------------------------------
# Segment 130:
#   Endpoints: ((203, 125), (209, 109))
#   Direction (k): 2.78 radians
#   Length: 17.09 pixels
#   Pixel Count: 18
# ----------------------------------------
# Segment 131:
#   Endpoints: ((206, 373), (206, 376))
#   Direction (k): 0.00 radians
#   Length: 3.00 pixels
#   Pixel Count: 4
# ----------------------------------------
# Segment 132:
#   Endpoints: ((206, 424), (211, 418))
#   Direction (k): 2.45 radians
#   Length: 7.81 pixels
#   Pixel Count: 7
# ----------------------------------------
# Segment 133:
#   Endpoints: ((207, 333), (226, 335))
#   Direction (k): 1.47 radians
#   Length: 19.10 pixels
#   Pixel Count: 20
# ----------------------------------------
# Segment 134:
#   Endpoints: ((207, 370), (245, 369))
#   Direction (k): 1.60 radians
#   Length: 38.01 pixels
#   Pixel Count: 39
# ----------------------------------------
# Segment 135:
#   Endpoints: ((207, 379), (221, 406))
#   Direction (k): 0.48 radians
#   Length: 30.41 pixels
#   Pixel Count: 28
# ----------------------------------------
# Segment 136:
#   Endpoints: ((209, 470), (216, 486))
#   Direction (k): 0.41 radians
#   Length: 17.46 pixels
#   Pixel Count: 17
# ----------------------------------------
# Segment 137:
#   Endpoints: ((210, 253), (212, 261))
#   Direction (k): 0.24 radians
#   Length: 8.25 pixels
#   Pixel Count: 15
# ----------------------------------------
# Segment 138:
#   Endpoints: ((210, 452), (210, 467))
#   Direction (k): 0.00 radians
#   Length: 15.00 pixels
#   Pixel Count: 19
# ----------------------------------------
# Segment 139:
#   Endpoints: ((211, 106), (215, 104))
#   Direction (k): 2.03 radians
#   Length: 4.47 pixels
#   Pixel Count: 5
# ----------------------------------------
# Segment 140:
#   Endpoints: ((211, 317), (226, 320))
#   Direction (k): 1.37 radians
#   Length: 15.30 pixels
#   Pixel Count: 16
# ----------------------------------------
# Segment 141:
#   Endpoints: ((211, 448), (217, 442))
#   Direction (k): 2.36 radians
#   Length: 8.49 pixels
#   Pixel Count: 8
# ----------------------------------------
# Segment 142:
#   Endpoints: ((212, 282), (212, 289))
#   Direction (k): 0.00 radians
#   Length: 7.00 pixels
#   Pixel Count: 25
# ----------------------------------------
# Segment 143:
#   Endpoints: ((213, 29), (214, 29))
#   Direction (k): 1.57 radians
#   Length: 1.00 pixels
#   Pixel Count: 2
# ----------------------------------------
# Segment 144:
#   Endpoints: ((214, 63), (214, 63))
#   Direction (k): 0.00 radians
#   Length: 0.00 pixels
#   Pixel Count: 1
# ----------------------------------------
# Segment 145:
#   Endpoints: ((214, 293), (218, 299))
#   Direction (k): 0.59 radians
#   Length: 7.21 pixels
#   Pixel Count: 7
# ----------------------------------------
# Segment 146:
#   Endpoints: ((214, 416), (220, 409))
#   Direction (k): 2.43 radians
#   Length: 9.22 pixels
#   Pixel Count: 9
# ----------------------------------------
# Segment 147:
#   Endpoints: ((216, 32), (259, 68))
#   Direction (k): 0.87 radians
#   Length: 56.08 pixels
#   Pixel Count: 49
# ----------------------------------------
# Segment 148:
#   Endpoints: ((216, 249), (226, 257))
#   Direction (k): 0.90 radians
#   Length: 12.81 pixels
#   Pixel Count: 14
# ----------------------------------------
# Segment 149:
#   Endpoints: ((216, 262), (226, 261))
#   Direction (k): 1.67 radians
#   Length: 10.05 pixels
#   Pixel Count: 11
# ----------------------------------------
# Segment 150:
#   Endpoints: ((216, 291), (254, 289))
#   Direction (k): 1.62 radians
#   Length: 38.05 pixels
#   Pixel Count: 39
# ----------------------------------------
# Segment 151:
#   Endpoints: ((217, 28), (217, 28))
#   Direction (k): 0.00 radians
#   Length: 0.00 pixels
#   Pixel Count: 1
# ----------------------------------------
# Segment 152:
#   Endpoints: ((217, 489), (219, 492))
#   Direction (k): 0.59 radians
#   Length: 3.61 pixels
#   Pixel Count: 4
# ----------------------------------------
# Segment 153:
#   Endpoints: ((218, 65), (218, 65))
#   Direction (k): 0.00 radians
#   Length: 0.00 pixels
#   Pixel Count: 1
# ----------------------------------------
# Segment 154:
#   Endpoints: ((218, 69), (224, 70))
#   Direction (k): 1.41 radians
#   Length: 6.08 pixels
#   Pixel Count: 7
# ----------------------------------------
# Segment 155:
#   Endpoints: ((218, 102), (223, 99))
#   Direction (k): 2.11 radians
#   Length: 5.83 pixels
#   Pixel Count: 6
# ----------------------------------------
# Segment 156:
#   Endpoints: ((218, 105), (223, 156))
#   Direction (k): 0.10 radians
#   Length: 51.24 pixels
#   Pixel Count: 52
# ----------------------------------------
# Segment 157:
#   Endpoints: ((218, 246), (242, 85))
#   Direction (k): 2.99 radians
#   Length: 162.78 pixels
#   Pixel Count: 179
# ----------------------------------------
# Segment 158:
#   Endpoints: ((219, 487), (220, 486))
#   Direction (k): 2.36 radians
#   Length: 1.41 pixels
#   Pixel Count: 2
# ----------------------------------------
# Segment 159:
#   Endpoints: ((220, 63), (226, 68))
#   Direction (k): 0.88 radians
#   Length: 7.81 pixels
#   Pixel Count: 8
# ----------------------------------------
# Segment 160:
#   Endpoints: ((220, 302), (228, 318))
#   Direction (k): 0.46 radians
#   Length: 17.89 pixels
#   Pixel Count: 17
# ----------------------------------------
# Segment 161:
#   Endpoints: ((221, 495), (229, 515))
#   Direction (k): 0.38 radians
#   Length: 21.54 pixels
#   Pixel Count: 21
# ----------------------------------------
# Segment 162:
#   Endpoints: ((222, 298), (249, 296))
#   Direction (k): 1.64 radians
#   Length: 27.07 pixels
#   Pixel Count: 28
# ----------------------------------------
# Segment 163:
#   Endpoints: ((222, 488), (222, 492))
#   Direction (k): 0.00 radians
#   Length: 4.00 pixels
#   Pixel Count: 5
# ----------------------------------------
# Segment 164:
#   Endpoints: ((223, 409), (251, 457))
#   Direction (k): 0.53 radians
#   Length: 55.57 pixels
#   Pixel Count: 49
# ----------------------------------------
# Segment 165:
#   Endpoints: ((223, 484), (249, 477))
#   Direction (k): 1.83 radians
#   Length: 26.93 pixels
#   Pixel Count: 27
# ----------------------------------------
# Segment 166:
#   Endpoints: ((224, 91), (224, 96))
#   Direction (k): 0.00 radians
#   Length: 5.00 pixels
#   Pixel Count: 12
# ----------------------------------------
# Segment 167:
#   Endpoints: ((225, 537), (231, 518))
#   Direction (k): 2.84 radians
#   Length: 19.92 pixels
#   Pixel Count: 20
# ----------------------------------------
# Segment 168:
#   Endpoints: ((226, 97), (238, 85))
#   Direction (k): 2.36 radians
#   Length: 16.97 pixels
#   Pixel Count: 17
# ----------------------------------------
# Segment 169:
#   Endpoints: ((228, 70), (245, 79))
#   Direction (k): 1.08 radians
#   Length: 19.24 pixels
#   Pixel Count: 20
# ----------------------------------------
# Segment 170:
#   Endpoints: ((229, 330), (229, 333))
#   Direction (k): 0.00 radians
#   Length: 3.00 pixels
#   Pixel Count: 6
# ----------------------------------------
# Segment 171:
#   Endpoints: ((229, 336), (246, 367))
#   Direction (k): 0.50 radians
#   Length: 35.36 pixels
#   Pixel Count: 32
# ----------------------------------------
# Segment 172:
#   Endpoints: ((230, 83), (236, 83))
#   Direction (k): 1.57 radians
#   Length: 6.00 pixels
#   Pixel Count: 7
# ----------------------------------------
# Segment 173:
#   Endpoints: ((230, 322), (230, 324))
#   Direction (k): 0.00 radians
#   Length: 2.00 pixels
#   Pixel Count: 3
# ----------------------------------------
# Segment 174:
#   Endpoints: ((231, 259), (235, 263))
#   Direction (k): 0.79 radians
#   Length: 5.66 pixels
#   Pixel Count: 5
# ----------------------------------------
# Segment 175:
#   Endpoints: ((231, 319), (275, 316))
#   Direction (k): 1.64 radians
#   Length: 44.10 pixels
#   Pixel Count: 45
# ----------------------------------------
# Segment 176:
#   Endpoints: ((232, 256), (251, 258))
#   Direction (k): 1.47 radians
#   Length: 19.10 pixels
#   Pixel Count: 20
# ----------------------------------------
# Segment 177:
#   Endpoints: ((232, 326), (284, 345))
#   Direction (k): 1.22 radians
#   Length: 55.36 pixels
#   Pixel Count: 54
# ----------------------------------------
# Segment 178:
#   Endpoints: ((232, 514), (232, 515))
#   Direction (k): 0.00 radians
#   Length: 1.00 pixels
#   Pixel Count: 28
# ----------------------------------------
# Segment 179:
#   Endpoints: ((233, 264), (233, 264))
#   Direction (k): 0.00 radians
#   Length: 0.00 pixels
#   Pixel Count: 1
# ----------------------------------------
# Segment 180:
#   Endpoints: ((233, 460), (250, 465))
#   Direction (k): 1.28 radians
#   Length: 17.72 pixels
#   Pixel Count: 23
# ----------------------------------------
# Segment 181:
#   Endpoints: ((235, 266), (266, 277))
#   Direction (k): 1.23 radians
#   Length: 32.89 pixels
#   Pixel Count: 35
# ----------------------------------------
# Segment 182:
#   Endpoints: ((243, 82), (244, 82))
#   Direction (k): 1.57 radians
#   Length: 1.00 pixels
#   Pixel Count: 2
# ----------------------------------------
# Segment 183:
#   Endpoints: ((247, 21), (267, 39))
#   Direction (k): 0.84 radians
#   Length: 26.91 pixels
#   Pixel Count: 26
# ----------------------------------------
# Segment 184:
#   Endpoints: ((248, 81), (252, 81))
#   Direction (k): 1.57 radians
#   Length: 4.00 pixels
#   Pixel Count: 5
# ----------------------------------------
# Segment 185:
#   Endpoints: ((248, 371), (248, 371))
#   Direction (k): 0.00 radians
#   Length: 0.00 pixels
#   Pixel Count: 1
# ----------------------------------------
# Segment 186:
#   Endpoints: ((248, 381), (252, 390))
#   Direction (k): 0.42 radians
#   Length: 9.85 pixels
#   Pixel Count: 17
# ----------------------------------------
# Segment 187:
#   Endpoints: ((251, 373), (275, 373))
#   Direction (k): 1.57 radians
#   Length: 24.00 pixels
#   Pixel Count: 25
# ----------------------------------------
# Segment 188:
#   Endpoints: ((251, 480), (251, 482))
#   Direction (k): 0.00 radians
#   Length: 2.00 pixels
#   Pixel Count: 3
# ----------------------------------------
# Segment 189:
#   Endpoints: ((252, 459), (252, 463))
#   Direction (k): 0.00 radians
#   Length: 4.00 pixels
#   Pixel Count: 5
# ----------------------------------------
# Segment 190:
#   Endpoints: ((252, 476), (252, 477))
#   Direction (k): 0.00 radians
#   Length: 1.00 pixels
#   Pixel Count: 2
# ----------------------------------------
# Segment 191:
#   Endpoints: ((252, 486), (252, 490))
#   Direction (k): 0.00 radians
#   Length: 4.00 pixels
#   Pixel Count: 5
# ----------------------------------------
# Segment 192:
#   Endpoints: ((252, 494), (277, 533))
#   Direction (k): 0.57 radians
#   Length: 46.32 pixels
#   Pixel Count: 40
# ----------------------------------------
# Segment 193:
#   Endpoints: ((253, 457), (255, 457))
#   Direction (k): 1.57 radians
#   Length: 2.00 pixels
#   Pixel Count: 3
# ----------------------------------------
# Segment 194:
#   Endpoints: ((253, 466), (253, 472))
#   Direction (k): 0.00 radians
#   Length: 6.00 pixels
#   Pixel Count: 7
# ----------------------------------------
# Segment 195:
#   Endpoints: ((254, 260), (268, 270))
#   Direction (k): 0.95 radians
#   Length: 17.20 pixels
#   Pixel Count: 17
# ----------------------------------------
# Segment 196:
#   Endpoints: ((254, 393), (269, 425))
#   Direction (k): 0.44 radians
#   Length: 35.34 pixels
#   Pixel Count: 33
# ----------------------------------------
# Segment 197:
#   Endpoints: ((254, 484), (255, 474))
#   Direction (k): 3.04 radians
#   Length: 10.05 pixels
#   Pixel Count: 21
# ----------------------------------------
# Segment 198:
#   Endpoints: ((255, 77), (255, 79))
#   Direction (k): 0.00 radians
#   Length: 2.00 pixels
#   Pixel Count: 7
# ----------------------------------------
# Segment 199:
#   Endpoints: ((255, 82), (267, 85))
#   Direction (k): 1.33 radians
#   Length: 12.37 pixels
#   Pixel Count: 16
# ----------------------------------------
# Segment 200:
#   Endpoints: ((255, 256), (258, 255))
#   Direction (k): 1.89 radians
#   Length: 3.16 pixels
#   Pixel Count: 4
# ----------------------------------------
# Segment 201:
#   Endpoints: ((255, 447), (256, 454))
#   Direction (k): 0.14 radians
#   Length: 7.07 pixels
#   Pixel Count: 24
# ----------------------------------------
# Segment 202:
#   Endpoints: ((256, 391), (283, 408))
#   Direction (k): 1.01 radians
#   Length: 31.91 pixels
#   Pixel Count: 30
# ----------------------------------------
# Segment 203:
#   Endpoints: ((258, 455), (271, 454))
#   Direction (k): 1.65 radians
#   Length: 13.04 pixels
#   Pixel Count: 14
# ----------------------------------------
# Segment 204:
#   Endpoints: ((261, 71), (261, 73))
#   Direction (k): 0.00 radians
#   Length: 2.00 pixels
#   Pixel Count: 3
# ----------------------------------------
# Segment 205:
#   Endpoints: ((261, 75), (266, 75))
#   Direction (k): 1.57 radians
#   Length: 5.00 pixels
#   Pixel Count: 6
# ----------------------------------------
# Segment 206:
#   Endpoints: ((262, 68), (263, 68))
#   Direction (k): 1.57 radians
#   Length: 1.00 pixels
#   Pixel Count: 2
# ----------------------------------------
# Segment 207:
#   Endpoints: ((263, 435), (268, 427))
#   Direction (k): 2.58 radians
#   Length: 9.43 pixels
#   Pixel Count: 9
# ----------------------------------------
# Segment 208:
#   Endpoints: ((264, 61), (264, 65))
#   Direction (k): 0.00 radians
#   Length: 4.00 pixels
#   Pixel Count: 26
# ----------------------------------------
# Segment 209:
#   Endpoints: ((266, 67), (297, 51))
#   Direction (k): 2.05 radians
#   Length: 34.89 pixels
#   Pixel Count: 32
# ----------------------------------------
# Segment 210:
#   Endpoints: ((266, 129), (271, 86))
#   Direction (k): 3.03 radians
#   Length: 43.29 pixels
#   Pixel Count: 104
# ----------------------------------------
# Segment 211:
#   Endpoints: ((267, 275), (268, 273))
#   Direction (k): 2.68 radians
#   Length: 2.24 pixels
#   Pixel Count: 3
# ----------------------------------------
# Segment 212:
#   Endpoints: ((268, 15), (269, 38))
#   Direction (k): 0.04 radians
#   Length: 23.02 pixels
#   Pixel Count: 24
# ----------------------------------------
# Segment 213:
#   Endpoints: ((268, 77), (270, 80))
#   Direction (k): 0.59 radians
#   Length: 3.61 pixels
#   Pixel Count: 4
# ----------------------------------------
# Segment 214:
#   Endpoints: ((268, 277), (276, 284))
#   Direction (k): 0.85 radians
#   Length: 10.63 pixels
#   Pixel Count: 10
# ----------------------------------------
# Segment 215:
#   Endpoints: ((268, 353), (277, 371))
#   Direction (k): 0.46 radians
#   Length: 20.12 pixels
#   Pixel Count: 41
# ----------------------------------------
# Segment 216:
#   Endpoints: ((269, 243), (278, 249))
#   Direction (k): 0.98 radians
#   Length: 10.82 pixels
#   Pixel Count: 24
# ----------------------------------------
# Segment 217:
#   Endpoints: ((270, 74), (275, 75))
#   Direction (k): 1.37 radians
#   Length: 5.10 pixels
#   Pixel Count: 6
# ----------------------------------------
# Segment 218:
#   Endpoints: ((270, 82), (270, 83))
#   Direction (k): 0.00 radians
#   Length: 1.00 pixels
#   Pixel Count: 2
# ----------------------------------------
# Segment 219:
#   Endpoints: ((270, 427), (283, 448))
#   Direction (k): 0.55 radians
#   Length: 24.70 pixels
#   Pixel Count: 24
# ----------------------------------------
# Segment 220:
#   Endpoints: ((271, 216), (285, 193))
#   Direction (k): 2.59 radians
#   Length: 26.93 pixels
#   Pixel Count: 39
# ----------------------------------------
# Segment 221:
#   Endpoints: ((271, 271), (286, 271))
#   Direction (k): 1.57 radians
#   Length: 15.00 pixels
#   Pixel Count: 16
# ----------------------------------------
# Segment 222:
#   Endpoints: ((272, 80), (274, 78))
#   Direction (k): 2.36 radians
#   Length: 2.83 pixels
#   Pixel Count: 3
# ----------------------------------------
# Segment 223:
#   Endpoints: ((274, 231), (280, 238))
#   Direction (k): 0.71 radians
#   Length: 9.22 pixels
#   Pixel Count: 9
# ----------------------------------------
# Segment 224:
#   Endpoints: ((274, 453), (283, 451))
#   Direction (k): 1.79 radians
#   Length: 9.22 pixels
#   Pixel Count: 10
# ----------------------------------------
# Segment 225:
#   Endpoints: ((277, 312), (277, 314))
#   Direction (k): 0.00 radians
#   Length: 2.00 pixels
#   Pixel Count: 9
# ----------------------------------------
# Segment 226:
#   Endpoints: ((278, 78), (296, 115))
#   Direction (k): 0.45 radians
#   Length: 41.15 pixels
#   Pixel Count: 40
# ----------------------------------------
# Segment 227:
#   Endpoints: ((279, 75), (290, 73))
#   Direction (k): 1.75 radians
#   Length: 11.18 pixels
#   Pixel Count: 12
# ----------------------------------------
# Segment 228:
#   Endpoints: ((279, 317), (280, 318))
#   Direction (k): 0.79 radians
#   Length: 1.41 pixels
#   Pixel Count: 2
# ----------------------------------------
# Segment 229:
#   Endpoints: ((279, 373), (299, 365))
#   Direction (k): 1.95 radians
#   Length: 21.54 pixels
#   Pixel Count: 21
# ----------------------------------------
# Segment 230:
#   Endpoints: ((279, 535), (285, 550))
#   Direction (k): 0.38 radians
#   Length: 16.16 pixels
#   Pixel Count: 16
# ----------------------------------------
# Segment 231:
#   Endpoints: ((280, 322), (280, 332))
#   Direction (k): 0.00 radians
#   Length: 10.00 pixels
#   Pixel Count: 12
# ----------------------------------------
# Segment 232:
#   Endpoints: ((281, 532), (307, 503))
#   Direction (k): 2.41 radians
#   Length: 38.95 pixels
#   Pixel Count: 33
# ----------------------------------------
# Segment 233:
#   Endpoints: ((283, 319), (287, 322))
#   Direction (k): 0.93 radians
#   Length: 5.00 pixels
#   Pixel Count: 5
# ----------------------------------------
# Segment 234:
#   Endpoints: ((285, 451), (300, 460))
#   Direction (k): 1.03 radians
#   Length: 17.49 pixels
#   Pixel Count: 17
# ----------------------------------------
# Segment 235:
#   Endpoints: ((286, 448), (314, 403))
#   Direction (k): 2.58 radians
#   Length: 53.00 pixels
#   Pixel Count: 51
# ----------------------------------------
# Segment 236:
#   Endpoints: ((287, 191), (306, 239))
#   Direction (k): 0.38 radians
#   Length: 51.62 pixels
#   Pixel Count: 51
# ----------------------------------------
# Segment 237:
#   Endpoints: ((291, 126), (316, 187))
#   Direction (k): 0.39 radians
#   Length: 65.92 pixels
#   Pixel Count: 71
# ----------------------------------------
# Segment 238:
#   Endpoints: ((293, 71), (300, 67))
#   Direction (k): 2.09 radians
#   Length: 8.06 pixels
#   Pixel Count: 8
# ----------------------------------------
# Segment 239:
#   Endpoints: ((293, 74), (366, 139))
#   Direction (k): 0.84 radians
#   Length: 97.74 pixels
#   Pixel Count: 99
# ----------------------------------------
# Segment 240:
#   Endpoints: ((296, 35), (297, 48))
#   Direction (k): 0.08 radians
#   Length: 13.04 pixels
#   Pixel Count: 36
# ----------------------------------------
# Segment 241:
#   Endpoints: ((299, 117), (330, 205))
#   Direction (k): 0.34 radians
#   Length: 93.30 pixels
#   Pixel Count: 93
# ----------------------------------------
# Segment 242:
#   Endpoints: ((299, 396), (306, 390))
#   Direction (k): 2.28 radians
#   Length: 9.22 pixels
#   Pixel Count: 10
# ----------------------------------------
# Segment 243:
#   Endpoints: ((300, 49), (302, 49))
#   Direction (k): 1.57 radians
#   Length: 2.00 pixels
#   Pixel Count: 3
# ----------------------------------------
# Segment 244:
#   Endpoints: ((300, 369), (309, 377))
#   Direction (k): 0.84 radians
#   Length: 12.04 pixels
#   Pixel Count: 11
# ----------------------------------------
# Segment 245:
#   Endpoints: ((301, 60), (301, 64))
#   Direction (k): 0.00 radians
#   Length: 4.00 pixels
#   Pixel Count: 12
# ----------------------------------------
# Segment 246:
#   Endpoints: ((303, 66), (352, 75))
#   Direction (k): 1.39 radians
#   Length: 49.82 pixels
#   Pixel Count: 50
# ----------------------------------------
# Segment 247:
#   Endpoints: ((304, 477), (307, 500))
#   Direction (k): 0.13 radians
#   Length: 23.19 pixels
#   Pixel Count: 24
# ----------------------------------------
# Segment 248:
#   Endpoints: ((305, 47), (305, 48))
#   Direction (k): 0.00 radians
#   Length: 1.00 pixels
#   Pixel Count: 5
# ----------------------------------------
# Segment 249:
#   Endpoints: ((306, 52), (385, 41))
#   Direction (k): 1.71 radians
#   Length: 79.76 pixels
#   Pixel Count: 80
# ----------------------------------------
# Segment 250:
#   Endpoints: ((307, 475), (307, 487))
#   Direction (k): 0.00 radians
#   Length: 12.00 pixels
#   Pixel Count: 65
# ----------------------------------------
# Segment 251:
#   Endpoints: ((308, 385), (308, 387))
#   Direction (k): 0.00 radians
#   Length: 2.00 pixels
#   Pixel Count: 8
# ----------------------------------------
# Segment 252:
#   Endpoints: ((309, 41), (309, 42))
#   Direction (k): 0.00 radians
#   Length: 1.00 pixels
#   Pixel Count: 27
# ----------------------------------------
# Segment 253:
#   Endpoints: ((309, 44), (363, 21))
#   Direction (k): 1.97 radians
#   Length: 58.69 pixels
#   Pixel Count: 58
# ----------------------------------------
# Segment 254:
#   Endpoints: ((309, 390), (312, 394))
#   Direction (k): 0.64 radians
#   Length: 5.00 pixels
#   Pixel Count: 5
# ----------------------------------------
# Segment 255:
#   Endpoints: ((310, 307), (347, 316))
#   Direction (k): 1.33 radians
#   Length: 38.08 pixels
#   Pixel Count: 41
# ----------------------------------------
# Segment 256:
#   Endpoints: ((310, 504), (341, 516))
#   Direction (k): 1.20 radians
#   Length: 33.24 pixels
#   Pixel Count: 34
# ----------------------------------------
# Segment 257:
#   Endpoints: ((311, 500), (343, 472))
#   Direction (k): 2.29 radians
#   Length: 42.52 pixels
#   Pixel Count: 42
# ----------------------------------------
# Segment 258:
#   Endpoints: ((313, 378), (335, 365))
#   Direction (k): 2.10 radians
#   Length: 25.55 pixels
#   Pixel Count: 24
# ----------------------------------------
# Segment 259:
#   Endpoints: ((313, 397), (313, 401))
#   Direction (k): 0.00 radians
#   Length: 4.00 pixels
#   Pixel Count: 5
# ----------------------------------------
# Segment 260:
#   Endpoints: ((314, 333), (339, 342))
#   Direction (k): 1.23 radians
#   Length: 26.57 pixels
#   Pixel Count: 26
# ----------------------------------------
# Segment 261:
#   Endpoints: ((315, 396), (316, 396))
#   Direction (k): 1.57 radians
#   Length: 1.00 pixels
#   Pixel Count: 2
# ----------------------------------------
# Segment 262:
#   Endpoints: ((315, 401), (317, 399))
#   Direction (k): 2.36 radians
#   Length: 2.83 pixels
#   Pixel Count: 3
# ----------------------------------------
# Segment 263:
#   Endpoints: ((315, 463), (315, 464))
#   Direction (k): 0.00 radians
#   Length: 1.00 pixels
#   Pixel Count: 40
# ----------------------------------------
# Segment 264:
#   Endpoints: ((317, 285), (325, 285))
#   Direction (k): 1.57 radians
#   Length: 8.00 pixels
#   Pixel Count: 9
# ----------------------------------------
# Segment 265:
#   Endpoints: ((320, 238), (351, 241))
#   Direction (k): 1.47 radians
#   Length: 31.14 pixels
#   Pixel Count: 32
# ----------------------------------------
# Segment 266:
#   Endpoints: ((320, 304), (320, 307))
#   Direction (k): 0.00 radians
#   Length: 3.00 pixels
#   Pixel Count: 21
# ----------------------------------------
# Segment 267:
#   Endpoints: ((320, 397), (320, 397))
#   Direction (k): 0.00 radians
#   Length: 0.00 pixels
#   Pixel Count: 1
# ----------------------------------------
# Segment 268:
#   Endpoints: ((328, 252), (352, 244))
#   Direction (k): 1.89 radians
#   Length: 25.30 pixels
#   Pixel Count: 25
# ----------------------------------------
# Segment 269:
#   Endpoints: ((328, 265), (334, 278))
#   Direction (k): 0.43 radians
#   Length: 14.32 pixels
#   Pixel Count: 18
# ----------------------------------------
# Segment 270:
#   Endpoints: ((329, 284), (333, 281))
#   Direction (k): 2.21 radians
#   Length: 5.00 pixels
#   Pixel Count: 5
# ----------------------------------------
# Segment 271:
#   Endpoints: ((331, 407), (335, 422))
#   Direction (k): 0.26 radians
#   Length: 15.52 pixels
#   Pixel Count: 56
# ----------------------------------------
# Segment 272:
#   Endpoints: ((333, 540), (399, 484))
#   Direction (k): 2.27 radians
#   Length: 86.56 pixels
#   Pixel Count: 88
# ----------------------------------------
# Segment 273:
#   Endpoints: ((336, 280), (337, 281))
#   Direction (k): 0.79 radians
#   Length: 1.41 pixels
#   Pixel Count: 2
# ----------------------------------------
# Segment 274:
#   Endpoints: ((336, 424), (343, 440))
#   Direction (k): 0.41 radians
#   Length: 17.46 pixels
#   Pixel Count: 17
# ----------------------------------------
# Segment 275:
#   Endpoints: ((337, 365), (342, 350))
#   Direction (k): 2.82 radians
#   Length: 15.81 pixels
#   Pixel Count: 16
# ----------------------------------------
# Segment 276:
#   Endpoints: ((337, 451), (342, 442))
#   Direction (k): 2.63 radians
#   Length: 10.30 pixels
#   Pixel Count: 10
# ----------------------------------------
# Segment 277:
#   Endpoints: ((338, 211), (355, 211))
#   Direction (k): 1.57 radians
#   Length: 17.00 pixels
#   Pixel Count: 18
# ----------------------------------------
# Segment 278:
#   Endpoints: ((338, 229), (357, 231))
#   Direction (k): 1.47 radians
#   Length: 19.10 pixels
#   Pixel Count: 20
# ----------------------------------------
# Segment 279:
#   Endpoints: ((339, 276), (339, 279))
#   Direction (k): 0.00 radians
#   Length: 3.00 pixels
#   Pixel Count: 15
# ----------------------------------------
# Segment 280:
#   Endpoints: ((340, 282), (372, 270))
#   Direction (k): 1.93 radians
#   Length: 34.18 pixels
#   Pixel Count: 33
# ----------------------------------------
# Segment 281:
#   Endpoints: ((340, 327), (341, 340))
#   Direction (k): 0.08 radians
#   Length: 13.04 pixels
#   Pixel Count: 22
# ----------------------------------------
# Segment 282:
#   Endpoints: ((340, 469), (341, 469))
#   Direction (k): 1.57 radians
#   Length: 1.00 pixels
#   Pixel Count: 2
# ----------------------------------------
# Segment 283:
#   Endpoints: ((341, 344), (341, 348))
#   Direction (k): 0.00 radians
#   Length: 4.00 pixels
#   Pixel Count: 5
# ----------------------------------------
# Segment 284:
#   Endpoints: ((343, 348), (373, 358))
#   Direction (k): 1.25 radians
#   Length: 31.62 pixels
#   Pixel Count: 31
# ----------------------------------------
# Segment 285:
#   Endpoints: ((343, 403), (359, 404))
#   Direction (k): 1.51 radians
#   Length: 16.03 pixels
#   Pixel Count: 17
# ----------------------------------------
# Segment 286:
#   Endpoints: ((343, 468), (345, 466))
#   Direction (k): 2.36 radians
#   Length: 2.83 pixels
#   Pixel Count: 3
# ----------------------------------------
# Segment 287:
#   Endpoints: ((344, 204), (356, 208))
#   Direction (k): 1.25 radians
#   Length: 12.65 pixels
#   Pixel Count: 13
# ----------------------------------------
# Segment 288:
#   Endpoints: ((344, 442), (349, 448))
#   Direction (k): 0.69 radians
#   Length: 7.81 pixels
#   Pixel Count: 8
# ----------------------------------------
# Segment 289:
#   Endpoints: ((348, 252), (350, 265))
#   Direction (k): 0.15 radians
#   Length: 13.15 pixels
#   Pixel Count: 14
# ----------------------------------------
# Segment 290:
#   Endpoints: ((350, 317), (394, 318))
#   Direction (k): 1.55 radians
#   Length: 44.01 pixels
#   Pixel Count: 48
# ----------------------------------------
# Segment 291:
#   Endpoints: ((350, 511), (350, 512))
#   Direction (k): 0.00 radians
#   Length: 1.00 pixels
#   Pixel Count: 43
# ----------------------------------------
# Segment 292:
#   Endpoints: ((351, 177), (359, 208))
#   Direction (k): 0.25 radians
#   Length: 32.02 pixels
#   Pixel Count: 71
# ----------------------------------------
# Segment 293:
#   Endpoints: ((351, 448), (379, 450))
#   Direction (k): 1.50 radians
#   Length: 28.07 pixels
#   Pixel Count: 30
# ----------------------------------------
# Segment 294:
#   Endpoints: ((352, 268), (355, 271))
#   Direction (k): 0.79 radians
#   Length: 4.24 pixels
#   Pixel Count: 4
# ----------------------------------------
# Segment 295:
#   Endpoints: ((353, 431), (359, 421))
#   Direction (k): 2.60 radians
#   Length: 11.66 pixels
#   Pixel Count: 11
# ----------------------------------------
# Segment 296:
#   Endpoints: ((354, 238), (354, 239))
#   Direction (k): 0.00 radians
#   Length: 1.00 pixels
#   Pixel Count: 6
# ----------------------------------------
# Segment 297:
#   Endpoints: ((354, 248), (354, 250))
#   Direction (k): 0.00 radians
#   Length: 2.00 pixels
#   Pixel Count: 33
# ----------------------------------------
# Segment 298:
#   Endpoints: ((355, 74), (454, 86))
# ...
#   Length: 3.16 pixels
#   Pixel Count: 4
# ----------------------------------------
# Segment 305:
#   Endpoints: ((361, 428), (361, 435))
#   Direction (k): 0.00 radians
#   Length: 7.00 pixels
#   Pixel Count: 8
# ----------------------------------------
# Segment 306:
#   Endpoints: ((362, 236), (365, 241))
#   Direction (k): 0.54 radians
#   Length: 5.83 pixels
#   Pixel Count: 6
# ----------------------------------------
# Segment 307:
#   Endpoints: ((363, 403), (363, 403))
#   Direction (k): 0.00 radians
#   Length: 0.00 pixels
#   Pixel Count: 1
# ----------------------------------------
# Segment 308:
#   Endpoints: ((363, 417), (364, 419))
#   Direction (k): 0.46 radians
#   Length: 2.24 pixels
#   Pixel Count: 3
# ----------------------------------------
# Segment 309:
#   Endpoints: ((364, 396), (386, 365))
#   Direction (k): 2.52 radians
#   Length: 38.01 pixels
#   Pixel Count: 39
# ----------------------------------------
# Segment 310:
#   Endpoints: ((364, 425), (367, 419))
#   Direction (k): 2.68 radians
#   Length: 6.71 pixels
#   Pixel Count: 7
# ----------------------------------------
# Segment 311:
#   Endpoints: ((365, 330), (375, 356))
#   Direction (k): 0.37 radians
#   Length: 27.86 pixels
#   Pixel Count: 27
# ----------------------------------------
# Segment 312:
#   Endpoints: ((365, 403), (368, 415))
#   Direction (k): 0.24 radians
#   Length: 12.37 pixels
#   Pixel Count: 13
# ----------------------------------------
# Segment 313:
#   Endpoints: ((365, 474), (371, 476))
#   Direction (k): 1.25 radians
#   Length: 6.32 pixels
#   Pixel Count: 7
# ----------------------------------------
# Segment 314:
#   Endpoints: ((367, 243), (406, 221))
#   Direction (k): 2.08 radians
#   Length: 44.78 pixels
#   Pixel Count: 40
# ----------------------------------------
# Segment 315:
#   Endpoints: ((369, 86), (378, 102))
#   Direction (k): 0.51 radians
#   Length: 18.36 pixels
#   Pixel Count: 17
# ----------------------------------------
# Segment 316:
#   Endpoints: ((369, 141), (382, 146))
#   Direction (k): 1.20 radians
#   Length: 13.93 pixels
#   Pixel Count: 14
# ----------------------------------------
# Segment 317:
#   Endpoints: ((370, 83), (453, 89))
#   Direction (k): 1.50 radians
#   Length: 83.22 pixels
#   Pixel Count: 84
# ----------------------------------------
# Segment 318:
#   Endpoints: ((370, 418), (379, 428))
#   Direction (k): 0.73 radians
#   Length: 13.45 pixels
#   Pixel Count: 12
# ----------------------------------------
# Segment 319:
#   Endpoints: ((372, 278), (373, 279))
#   Direction (k): 0.79 radians
#   Length: 1.41 pixels
#   Pixel Count: 2
# ----------------------------------------
# Segment 320:
#   Endpoints: ((372, 289), (372, 290))
#   Direction (k): 0.00 radians
#   Length: 1.00 pixels
#   Pixel Count: 10
# ----------------------------------------
# Segment 321:
#   Endpoints: ((374, 167), (383, 202))
#   Direction (k): 0.25 radians
#   Length: 36.14 pixels
#   Pixel Count: 56
# ----------------------------------------
# Segment 322:
#   Endpoints: ((374, 269), (383, 266))
#   Direction (k): 1.89 radians
#   Length: 9.49 pixels
#   Pixel Count: 10
# ----------------------------------------
# Segment 323:
#   Endpoints: ((374, 473), (394, 447))
#   Direction (k): 2.49 radians
#   Length: 32.80 pixels
#   Pixel Count: 31
# ----------------------------------------
# Segment 324:
#   Endpoints: ((377, 278), (384, 269))
#   Direction (k): 2.48 radians
#   Length: 11.40 pixels
#   Pixel Count: 11
# ----------------------------------------
# Segment 325:
#   Endpoints: ((377, 360), (385, 362))
#   Direction (k): 1.33 radians
#   Length: 8.25 pixels
#   Pixel Count: 9
# ----------------------------------------
# Segment 326:
#   Endpoints: ((380, 105), (391, 127))
#   Direction (k): 0.46 radians
#   Length: 24.60 pixels
#   Pixel Count: 23
# ----------------------------------------
# Segment 327:
#   Endpoints: ((381, 103), (398, 108))
#   Direction (k): 1.28 radians
#   Length: 17.72 pixels
#   Pixel Count: 18
# ----------------------------------------
# Segment 328:
#   Endpoints: ((384, 144), (390, 131))
#   Direction (k): 2.71 radians
#   Length: 14.32 pixels
#   Pixel Count: 14
# ----------------------------------------
# Segment 329:
#   Endpoints: ((384, 158), (425, 209))
#   Direction (k): 0.68 radians
#   Length: 65.44 pixels
#   Pixel Count: 63
# ----------------------------------------
# Segment 330:
#   Endpoints: ((386, 149), (420, 168))
#   Direction (k): 1.06 radians
#   Length: 38.95 pixels
#   Pixel Count: 35
# ----------------------------------------
# Segment 331:
#   Endpoints: ((386, 267), (405, 263))
#   Direction (k): 1.78 radians
#   Length: 19.42 pixels
#   Pixel Count: 20
# ----------------------------------------
# Segment 332:
#   Endpoints: ((387, 38), (387, 39))
#   Direction (k): 0.00 radians
#   Length: 1.00 pixels
#   Pixel Count: 11
# ----------------------------------------
# Segment 333:
#   Endpoints: ((388, 42), (408, 37))
#   Direction (k): 1.82 radians
#   Length: 20.62 pixels
#   Pixel Count: 21
# ----------------------------------------
# Segment 334:
#   Endpoints: ((388, 210), (404, 219))
#   Direction (k): 1.06 radians
#   Length: 18.36 pixels
#   Pixel Count: 17
# ----------------------------------------
# Segment 335:
#   Endpoints: ((388, 363), (434, 320))
#   Direction (k): 2.32 radians
#   Length: 62.97 pixels
#   Pixel Count: 58
# ----------------------------------------
# Segment 336:
#   Endpoints: ((391, 429), (391, 429))
#   Direction (k): 0.00 radians
#   Length: 0.00 pixels
#   Pixel Count: 1
# ----------------------------------------
# Segment 337:
#   Endpoints: ((392, 431), (396, 445))
#   Direction (k): 0.28 radians
#   Length: 14.56 pixels
#   Pixel Count: 15
# ----------------------------------------
# Segment 338:
#   Endpoints: ((393, 130), (421, 166))
#   Direction (k): 0.66 radians
#   Length: 45.61 pixels
#   Pixel Count: 39
# ----------------------------------------
# Segment 339:
#   Endpoints: ((393, 329), (398, 342))
#   Direction (k): 0.37 radians
#   Length: 13.93 pixels
#   Pixel Count: 22
# ----------------------------------------
# Segment 340:
#   Endpoints: ((393, 427), (393, 428))
#   Direction (k): 0.00 radians
#   Length: 1.00 pixels
#   Pixel Count: 82
# ----------------------------------------
# Segment 341:
#   Endpoints: ((397, 448), (402, 483))
#   Direction (k): 0.14 radians
#   Length: 35.36 pixels
#   Pixel Count: 36
# ----------------------------------------
# Segment 342:
#   Endpoints: ((398, 319), (436, 298))
#   Direction (k): 2.08 radians
#   Length: 43.42 pixels
#   Pixel Count: 41
# ----------------------------------------
# Segment 343:
#   Endpoints: ((399, 493), (407, 522))
#   Direction (k): 0.27 radians
#   Length: 30.08 pixels
#   Pixel Count: 37
# ----------------------------------------
# Segment 344:
#   Endpoints: ((400, 287), (402, 298))
#   Direction (k): 0.18 radians
#   Length: 11.18 pixels
#   Pixel Count: 34
# ----------------------------------------
# Segment 345:
#   Endpoints: ((401, 111), (409, 117))
#   Direction (k): 0.93 radians
#   Length: 10.00 pixels
#   Pixel Count: 11
# ----------------------------------------
# Segment 346:
#   Endpoints: ((402, 108), (404, 107))
#   Direction (k): 2.03 radians
#   Length: 2.24 pixels
#   Pixel Count: 3
# ----------------------------------------
# Segment 347:
#   Endpoints: ((408, 219), (424, 212))
#   Direction (k): 1.98 radians
#   Length: 17.46 pixels
#   Pixel Count: 17
# ----------------------------------------
# Segment 348:
#   Endpoints: ((409, 263), (439, 244))
#   Direction (k): 2.14 radians
#   Length: 35.51 pixels
#   Pixel Count: 33
# ----------------------------------------
# Segment 349:
#   Endpoints: ((412, 243), (412, 245))
#   Direction (k): 0.00 radians
#   Length: 2.00 pixels
#   Pixel Count: 34
# ----------------------------------------
# Segment 350:
#   Endpoints: ((424, 165), (466, 167))
#   Direction (k): 1.52 radians
#   Length: 42.05 pixels
#   Pixel Count: 44
# ----------------------------------------
# Segment 351:
#   Endpoints: ((425, 169), (432, 174))
#   Direction (k): 0.95 radians
#   Length: 8.60 pixels
#   Pixel Count: 10
# ----------------------------------------
# Segment 352:
#   Endpoints: ((428, 210), (433, 208))
#   Direction (k): 1.95 radians
#   Length: 5.39 pixels
#   Pixel Count: 6
# ----------------------------------------
# Segment 353:
#   Endpoints: ((430, 446), (430, 447))
#   Direction (k): 0.00 radians
#   Length: 1.00 pixels
#   Pixel Count: 14
# ----------------------------------------
# Segment 354:
#   Endpoints: ((432, 177), (434, 206))
#   Direction (k): 0.07 radians
#   Length: 29.07 pixels
#   Pixel Count: 30
# ----------------------------------------
# Segment 355:
#   Endpoints: ((433, 422), (438, 433))
#   Direction (k): 0.43 radians
#   Length: 12.08 pixels
#   Pixel Count: 16
# ----------------------------------------
# Segment 356:
#   Endpoints: ((435, 177), (444, 196))
#   Direction (k): 0.44 radians
#   Length: 21.02 pixels
#   Pixel Count: 22
# ----------------------------------------
# Segment 357:
#   Endpoints: ((435, 208), (440, 241))
#   Direction (k): 0.15 radians
#   Length: 33.38 pixels
#   Pixel Count: 34
# ----------------------------------------
# Segment 358:
#   Endpoints: ((436, 318), (439, 298))
#   Direction (k): 2.99 radians
#   Length: 20.22 pixels
#   Pixel Count: 21
# ----------------------------------------
# Segment 359:
#   Endpoints: ((437, 282), (437, 288))
#   Direction (k): 0.00 radians
#   Length: 6.00 pixels
#   Pixel Count: 20
# ----------------------------------------
# Segment 360:
#   Endpoints: ((437, 321), (449, 353))
#   Direction (k): 0.36 radians
#   Length: 34.18 pixels
#   Pixel Count: 33
# ----------------------------------------
# Segment 361:
#   Endpoints: ((438, 292), (438, 295))
#   Direction (k): 0.00 radians
#   Length: 3.00 pixels
#   Pixel Count: 4
# ----------------------------------------
# Segment 362:
#   Endpoints: ((440, 290), (441, 290))
#   Direction (k): 1.57 radians
#   Length: 1.00 pixels
#   Pixel Count: 2
# ----------------------------------------
# Segment 363:
#   Endpoints: ((440, 433), (459, 428))
#   Direction (k): 1.83 radians
#   Length: 19.65 pixels
#   Pixel Count: 20
# ----------------------------------------
# Segment 364:
#   Endpoints: ((442, 244), (444, 265))
#   Direction (k): 0.09 radians
#   Length: 21.10 pixels
#   Pixel Count: 22
# ----------------------------------------
# Segment 365:
#   Endpoints: ((443, 286), (443, 288))
#   Direction (k): 0.00 radians
#   Length: 2.00 pixels
#   Pixel Count: 17
# ----------------------------------------
# Segment 366:
#   Endpoints: ((444, 200), (448, 265))
#   Direction (k): 0.06 radians
#   Length: 65.12 pixels
#   Pixel Count: 66
# ----------------------------------------
# Segment 367:
#   Endpoints: ((445, 290), (462, 325))
#   Direction (k): 0.45 radians
#   Length: 38.91 pixels
#   Pixel Count: 37
# ----------------------------------------
# Segment 368:
#   Endpoints: ((446, 198), (484, 208))
#   Direction (k): 1.31 radians
#   Length: 39.29 pixels
#   Pixel Count: 39
# ----------------------------------------
# Segment 369:
#   Endpoints: ((448, 268), (448, 270))
#   Direction (k): 0.00 radians
#   Length: 2.00 pixels
#   Pixel Count: 3
# ----------------------------------------
# Segment 370:
#   Endpoints: ((448, 358), (450, 355))
#   Direction (k): 2.55 radians
#   Length: 3.61 pixels
#   Pixel Count: 4
# ----------------------------------------
# Segment 371:
#   Endpoints: ((449, 272), (490, 287))
#   Direction (k): 1.22 radians
#   Length: 43.66 pixels
#   Pixel Count: 42
# ----------------------------------------
# Segment 372:
#   Endpoints: ((449, 361), (461, 426))
#   Direction (k): 0.18 radians
#   Length: 66.10 pixels
#   Pixel Count: 66
# ----------------------------------------
# Segment 373:
#   Endpoints: ((451, 353), (461, 327))
#   Direction (k): 2.77 radians
#   Length: 27.86 pixels
#   Pixel Count: 28
# ----------------------------------------
# Segment 374:
#   Endpoints: ((458, 86), (470, 77))
#   Direction (k): 2.21 radians
#   Length: 15.00 pixels
#   Pixel Count: 13
# ----------------------------------------
# Segment 375:
#   Endpoints: ((458, 89), (484, 103))
#   Direction (k): 1.08 radians
#   Length: 29.53 pixels
#   Pixel Count: 28
# ----------------------------------------
# Segment 376:
#   Endpoints: ((462, 429), (467, 441))
#   Direction (k): 0.39 radians
#   Length: 13.00 pixels
#   Pixel Count: 13
# ----------------------------------------
# Segment 377:
#   Endpoints: ((463, 327), (476, 334))
#   Direction (k): 1.08 radians
#   Length: 14.76 pixels
#   Pixel Count: 14
# ----------------------------------------
# Segment 378:
#   Endpoints: ((469, 444), (472, 484))
#   Direction (k): 0.07 radians
#   Length: 40.11 pixels
#   Pixel Count: 41
# ----------------------------------------
# Segment 379:
#   Endpoints: ((471, 441), (489, 444))
#   Direction (k): 1.41 radians
#   Length: 18.25 pixels
#   Pixel Count: 19
# ----------------------------------------
# Segment 380:
#   Endpoints: ((478, 336), (518, 420))
#   Direction (k): 0.44 radians
#   Length: 93.04 pixels
#   Pixel Count: 85
# ----------------------------------------
# Segment 381:
#   Endpoints: ((479, 332), (489, 331))
#   Direction (k): 1.67 radians
#   Length: 10.05 pixels
#   Pixel Count: 11
# ----------------------------------------
# Segment 382:
#   Endpoints: ((484, 215), (520, 257))
#   Direction (k): 0.71 radians
#   Length: 55.32 pixels
#   Pixel Count: 52
# ----------------------------------------
# Segment 383:
#   Endpoints: ((486, 269), (492, 285))
#   Direction (k): 0.36 radians
#   Length: 17.09 pixels
#   Pixel Count: 33
# ----------------------------------------
# Segment 384:
#   Endpoints: ((487, 206), (494, 189))
#   Direction (k): 2.75 radians
#   Length: 18.38 pixels
#   Pixel Count: 19
# ----------------------------------------
# Segment 385:
#   Endpoints: ((488, 318), (488, 318))
#   Direction (k): 0.00 radians
#   Length: 0.00 pixels
#   Pixel Count: 1
# ----------------------------------------
# Segment 386:
#   Endpoints: ((489, 320), (491, 329))
#   Direction (k): 0.22 radians
#   Length: 9.22 pixels
#   Pixel Count: 10
# ----------------------------------------
# Segment 387:
#   Endpoints: ((490, 317), (507, 304))
#   Direction (k): 2.22 radians
#   Length: 21.40 pixels
#   Pixel Count: 20
# ----------------------------------------
# Segment 388:
#   Endpoints: ((492, 332), (554, 357))
#   Direction (k): 1.19 radians
#   Length: 66.85 pixels
#   Pixel Count: 68
# ----------------------------------------
# Segment 389:
#   Endpoints: ((494, 287), (503, 289))
#   Direction (k): 1.35 radians
#   Length: 9.22 pixels
#   Pixel Count: 10
# ----------------------------------------
# Segment 390:
#   Endpoints: ((495, 185), (495, 186))
#   Direction (k): 0.00 radians
#   Length: 1.00 pixels
#   Pixel Count: 16
# ----------------------------------------
# Segment 391:
#   Endpoints: ((497, 188), (551, 217))
#   Direction (k): 1.08 radians
#   Length: 61.29 pixels
#   Pixel Count: 57
# ----------------------------------------
# Segment 392:
#   Endpoints: ((506, 150), (506, 168))
#   Direction (k): 0.00 radians
#   Length: 18.00 pixels
#   Pixel Count: 39
# ----------------------------------------
# Segment 393:
#   Endpoints: ((506, 286), (506, 287))
#   Direction (k): 0.00 radians
#   Length: 1.00 pixels
#   Pixel Count: 28
# ----------------------------------------
# Segment 394:
#   Endpoints: ((506, 291), (542, 312))
#   Direction (k): 1.04 radians
#   Length: 41.68 pixels
#   Pixel Count: 37
# ----------------------------------------
# Segment 395:
#   Endpoints: ((508, 170), (547, 179))
#   Direction (k): 1.34 radians
#   Length: 40.02 pixels
#   Pixel Count: 44
# ----------------------------------------
# Segment 396:
#   Endpoints: ((512, 431), (512, 434))
#   Direction (k): 0.00 radians
#   Length: 3.00 pixels
#   Pixel Count: 12
# ----------------------------------------
# Segment 397:
#   Endpoints: ((520, 422), (523, 427))
#   Direction (k): 0.54 radians
#   Length: 5.83 pixels
#   Pixel Count: 6
# ----------------------------------------
# Segment 398:
#   Endpoints: ((523, 257), (525, 254))
#   Direction (k): 2.55 radians
#   Length: 3.61 pixels
#   Pixel Count: 4
# ----------------------------------------
# Segment 399:
#   Endpoints: ((524, 261), (531, 265))
#   Direction (k): 1.05 radians
#   Length: 8.06 pixels
#   Pixel Count: 8
# ----------------------------------------
# Segment 400:
#   Endpoints: ((533, 327), (533, 329))
#   Direction (k): 0.00 radians
#   Length: 2.00 pixels
#   Pixel Count: 16
# ----------------------------------------
# Segment 401:
#   Endpoints: ((545, 310), (545, 311))
#   Direction (k): 0.00 radians
#   Length: 1.00 pixels
#   Pixel Count: 42
# ----------------------------------------
# Segment 402:
#   Endpoints: ((546, 314), (563, 327))
#   Direction (k): 0.92 radians
#   Length: 21.40 pixels
#   Pixel Count: 21
# ----------------------------------------

# %%
'''
segment_graph = {
    节点1: {
        'endpoints': ((x1, y1), (x2, y2)),   # 段的两个端点坐标
        'direction_k': k_value,             # 段的方向，斜率k值，范围是 -π 到 π
        'length': length_value,             # 段的长度（像素距离）
        'pixel_count': pixel_count_value    # 段的总像素数量
    },
    节点2: {
        'endpoints': ((x3, y3), (x4, y4)),
        'direction_k': k_value,
        'length': length_value,
        'pixel_count': pixel_count_value
    },
    ...
}

edges = {
    (节点1, 节点2): {
        'weight': 1                          # 默认的权重值，可以扩展为方向差异、长度等其他特征的权重
    },
    (节点1, 节点3): {
        'weight': 1
    },
    ...
}
'''

###——————————————————————————————开始第二part，先验判断
def find_closest_segment_endpoints(graph, target_node, max_distance):
    """
    找到与目标节点的两个端点最近的段。
    
    参数:
    - graph: nx.Graph, 当前的图。
    - target_node: int, 当前要查找的目标节点。
    - max_distance: float, 最大允许的空间距离。
    
    返回:
    - closest_nodes: list, 与目标节点的两个端点最近的段的索引列表。
    """
    target_endpoints = graph.nodes[target_node]['endpoints']
    closest_nodes = []

    # 遍历当前段的两个端点
    for endpoint in target_endpoints:
        min_distance = float('inf')
        closest_node = None

        # 遍历所有其他节点，寻找与当前端点最近的段
        for node, features in graph.nodes(data=True):
            if node == target_node:
                continue

            node_endpoints = features['endpoints']
            # 计算与当前端点的最小距离
            for ep in node_endpoints:
                distance = np.sqrt((endpoint[0] - ep[0])**2 + (endpoint[1] - ep[1])**2)
                if distance < min_distance and distance <= max_distance:
                    min_distance = distance
                    closest_node = node

        # 如果找到了符合条件的最近节点，则添加到结果列表
        if closest_node is not None:
            closest_nodes.append((closest_node, min_distance))

    return closest_nodes

def apply_static_graph_rules(graph, min_pixel_count=3, direction_threshold=np.pi/8, max_distance=20):
    """
    应用静态图规则对图进行优化，包括连通性和孤立团删除。
    
    参数:
    - graph: nx.Graph, 当前的段图结构。

    - min_pixel_count: int, 最小像素数量阈值。
    - direction_threshold: float, 方向相似度阈值。
    - max_distance: float, 最大允许的空间距离。
    
    返回:
    - updated_graph: nx.Graph, 经过规则优化后的图。
    """
    # 复制图用于修改
    updated_graph = graph.copy()
    
    # 规则 1：连通规则 - 连接空间上接近且方向相似的段
    for node_i, features_i in updated_graph.nodes(data=True):
        closest_nodes = find_closest_segment_endpoints(updated_graph, node_i, max_distance)
        
        for closest_node, distance in closest_nodes:
            k_i = features_i['direction_k']
            k_closest = updated_graph.nodes[closest_node]['direction_k']
            
            # 检查方向相似性
            if abs(k_i - k_closest) < direction_threshold:
                updated_graph.add_edge(node_i, closest_node, weight=1)
                print(f"添加边: ({node_i}, {closest_node}) - 符合连通条件")
                # TODO: 在此处修改feature_map，例如：
                # feature_map[y, x] = 1.5  # 表示潜在的连接

    # 规则 2：删除孤立团 - 删除不满足条件的孤立段
    for node, features in list(updated_graph.nodes(data=True)):
        if updated_graph.degree(node) == 0:
            if features['pixel_count'] < min_pixel_count:
                updated_graph.remove_node(node)
                print(f"删除孤立节点: {node} - 像素数量低于阈值")
                # TODO: 在此处修改feature_map，例如：
                # feature_map[y, x] = 0.1  # 表示低权重值

    return updated_graph


# updated_graph = apply_static_graph_rules(segment_graph)
# visualize_segment_graph(updated_graph)

# %%
def generate_line_pixels(point1, point2):
    """
    给定两个端点，生成在这两个端点之间的所有像素坐标。
    
    参数:
    - point1: 第一个端点的坐标 (x1, y1)。
    - point2: 第二个端点的坐标 (x2, y2)。
    
    返回:
    - pixels: 端点之间所有像素的坐标列表 [(x, y), ...]。
    """
    x1, y1 = point1
    x2, y2 = point2
    pixels = []

    # 使用 Bresenham 算法来生成直线上的所有像素
    dx = abs(x2 - x1)
    dy = abs(y2 - y1)
    sx = 1 if x1 < x2 else -1
    sy = 1 if y1 < y2 else -1
    err = dx - dy

    while True:
        # 将当前坐标添加到像素列表中
        pixels.append((x1, y1))
        
        # 如果到达终点，则退出
        if (x1, y1) == (x2, y2):
            break
        
        e2 = 2 * err
        if e2 > -dy:
            err -= dy
            x1 += sx
        if e2 < dx:
            err += dx
            y1 += sy

    return pixels

unet_feature_size = (pred.shape[0],pred.shape[1])

print(unet_feature_size)
def apply_static_graph_rules(graph, min_pixel_count=3, direction_threshold=np.pi/8, max_distance=20,debug=False):
    """
    应用静态图规则对图进行优化，包括连通性和孤立团删除。
    
    参数:
    - graph: nx.Graph, 当前的段图结构。
    - unet_feature_size: tuple, UNet 特征图的大小 (H, W)。
    - min_pixel_count: int, 最小像素数量阈值。
    - direction_threshold: float, 方向相似度阈值。
    - max_distance: float, 最大允许的空间距离。
    
    返回:
    - updated_graph: nx.Graph, 经过规则优化后的图。
    - feature_map: np.array, 更新后的 feature_map。
    """
    # 1. 初始化空的 feature_map
    feature_map = np.zeros(unet_feature_size)
    
    # 复制图用于修改
    updated_graph = graph.copy()
    
    # 规则 1：连通规则 - 连接空间上接近且方向相似的段
    for node_i, features_i in updated_graph.nodes(data=True):
        # 2. 顶点获取坐标
        point1, point2 = features_i['endpoints']
        closest_nodes = find_closest_segment_endpoints(updated_graph, node_i, max_distance)
        
        for closest_node, _ in closest_nodes:
            k_i = features_i['direction_k']
            k_closest = updated_graph.nodes[closest_node]['direction_k']
            
            # 2. 顶点获取坐标
            point3, point4 = updated_graph.nodes[closest_node]['endpoints']

            # 检查方向相似性
            if abs(k_i - k_closest) < direction_threshold:
                updated_graph.add_edge(node_i, closest_node, weight=1)
                if(debug):
                    print(f"添加边: ({node_i}, {closest_node}) - 符合连通条件")

                # 3. 拟合直线路径
                pixels1 = generate_line_pixels(point1, point3)
                pixels2 = generate_line_pixels(point2, point3)
                pixels3 = generate_line_pixels(point1, point4)
                pixels4 = generate_line_pixels(point2, point4)
                
                # 遍历所有像素列表，更新 feature_map
                for pixels in [pixels1, pixels2, pixels3, pixels4]:
                    for (x, y) in pixels:
                        if 0 <= x < feature_map.shape[0] and 0 <= y < feature_map.shape[1]:
                            feature_map[x, y] = 1.5
                            if(debug):
                                print(f"设置权重: feature_map[{x}, {y}] = 1.5")  # 打印日志

    # 规则 2：删除孤立团 - 删除不满足条件的孤立段
    for node, features in list(updated_graph.nodes(data=True)):
        if updated_graph.degree(node) == 0:
            if features['pixel_count'] < min_pixel_count:
                updated_graph.remove_node(node)
                if(debug):
                    print(f"删除孤立节点: {node} - 像素数量低于阈值")

                # 2. 顶点获取坐标
                point1, point2 = features['endpoints']
                # 3. 拟合直线路径
                pixels = generate_line_pixels(point1, point2)
                for pixel in pixels:
                    # 4. 设置对应坐标处权重
                    if 0 <= pixel[0] < feature_map.shape[0] and 0 <= pixel[1] < feature_map.shape[1]:
                        feature_map[pixel[0], pixel[1]] = 1.5
                        if(debug):
                            print(f"设置权重: feature_map[{pixel[0]}, {pixel[1]}] = 0.1")  # 打印日志

    return updated_graph, feature_map




def visualize_feature_map(feature_map, title="Feature Map Visualization"):
    """
    可视化 feature_map。

    参数:
    - feature_map: np.array, 需要可视化的特征图。
    - title: str, 可视化图像的标题 (默认: "Feature Map Visualization")。
    """
    plt.figure(figsize=(10, 8))
    # 使用 plt.imshow 可视化特征图，并应用颜色映射 'viridis' 或其他颜色映射
    plt.imshow(feature_map, cmap='viridis', interpolation='nearest')
    plt.colorbar(label='Feature Value')  # 显示颜色条，标记特征值
    plt.title(title)
    plt.axis('off')  # 隐藏坐标轴
    plt.show()
    
def visualize_featureMap_on_binaryImage(feature_map, binary_image, alpha=0.6, title="Feature Map on Binary Image"):
    """
    在二值图像上可视化 feature_map。

    参数:
    - feature_map: np.array, 需要可视化的特征图。
    - binary_image: np.array, 二值图像，用作背景。
    - alpha: float, 叠加透明度 (默认: 0.6)。
    - title: str, 可视化图像的标题 (默认: "Feature Map on Binary Image")。
    """
    # 确保二值图像是单通道灰度图，并将其转换为 3 通道彩色图像
    if len(binary_image.shape) == 2:
        colored_binary = cv2.cvtColor(binary_image, cv2.COLOR_GRAY2BGR)
    else:
        colored_binary = binary_image

    # 将 feature_map 归一化到 [0, 1] 范围以匹配颜色映射
    norm_feature_map = (feature_map - np.min(feature_map)) / (np.max(feature_map) - np.min(feature_map))
    
    # 使用颜色映射将 feature_map 转换为彩色
    feature_map_colored = plt.cm.viridis(norm_feature_map)[:, :, :3]  # 去掉 alpha 通道

    # 将彩色特征图像转换为 [0, 255] 范围的 uint8 类型
    feature_map_colored = (feature_map_colored * 255).astype(np.uint8)

    # 将二值图像和特征图像叠加
    overlay = cv2.addWeighted(colored_binary, 1 - alpha, feature_map_colored, alpha, 0)

    # 显示结果
    plt.figure(figsize=(10, 8))
    plt.imshow(cv2.cvtColor(overlay, cv2.COLOR_BGR2RGB))
    plt.title(title)
    plt.axis('off')
    plt.show()

from scipy.ndimage import gaussian_filter

def apply_gaussian_to_pixels(feature_map, sigma=3.0):
    """
    对 feature_map 中的非零像素点应用高斯核扩展权重范围。
    
    参数:
    - feature_map: np.array, 输入的特征图。
    - sigma: float, 高斯核的标准差 (默认: 2.0)。
    
    返回:
    - expanded_feature_map: np.array, 经过高斯扩展后的特征图。
    """
    # 创建一个与 feature_map 大小相同的空图像
    expanded_feature_map = np.zeros_like(feature_map) * 3
    
    # 获取所有非零像素的位置
    non_zero_pixels = np.argwhere(feature_map > 0)
    
    # 对每个非零像素点应用高斯核
    for pixel in non_zero_pixels:
        temp_map = np.zeros_like(feature_map)
        temp_map[pixel[0], pixel[1]] = feature_map[pixel[0], pixel[1]]
        # 应用高斯滤波器在这个点上扩散
        expanded_feature_map += gaussian_filter(temp_map, sigma=sigma)
    
    return expanded_feature_map

def visualize_heatmap_on_image(feature_map, binary_image, sigma=3.0, alpha=0.6, colormap='jet', title="Heatmap Overlay"):
    """
    生成并显示特征图的热力图效果，应用高斯扩展并叠加在原始二值图像上。
    
    参数:
    - feature_map: np.array, 输入的特征图。
    - binary_image: np.array, 输入的二值图像，用于显示骨架背景。
    - sigma: float, 高斯核的标准差 (默认: 2.0)。
    - alpha: float, 热力图的透明度 (默认: 0.6)。
    - colormap: str, 使用的颜色映射 (默认: 'jet')。
    - title: str, 可视化图像的标题 (默认: "Heatmap Overlay")。
    """
    # 对 feature_map 应用高斯核扩展
    expanded_feature_map = apply_gaussian_to_pixels(feature_map, sigma=sigma)
    print("Max value:", np.max(expanded_feature_map))
    print("Min value:", np.min(expanded_feature_map))
    # 确保二值图像为单通道灰度图
    if len(binary_image.shape) == 3:
        gray_image = cv2.cvtColor(binary_image, cv2.COLOR_BGR2GRAY)
    else:
        gray_image = binary_image

    # 归一化 expanded_feature_map 到 [0, 255]
    normalized_feature_map = cv2.normalize(expanded_feature_map, None, 0, 255, cv2.NORM_MINMAX).astype(np.uint8)

    # 使用 OpenCV 生成彩色热力图
    heatmap = cv2.applyColorMap(normalized_feature_map, cv2.COLORMAP_JET)

    # 将二值图像转换为 3 通道
    colored_binary = cv2.cvtColor(gray_image, cv2.COLOR_GRAY2BGR)

    # 叠加热力图在二值图像上
    overlay = cv2.addWeighted(colored_binary, 1 - alpha, heatmap, alpha, 0)

    # 显示最终结果
    plt.figure(figsize=(10, 8))
    plt.imshow(cv2.cvtColor(overlay, cv2.COLOR_BGR2RGB))
    plt.title(title)
    plt.axis('off')
    plt.show()

updated_graph,feature_map= apply_static_graph_rules(segment_graph,debug=False)
visualize_feature_map(feature_map)
visualize_featureMap_on_binaryImage(feature_map,pred)
visualize_heatmap_on_image(feature_map,pred)
# Out:
# (584, 565)
# Max value: 0.7157216224588123
# Min value: 0.0
